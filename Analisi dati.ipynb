# %% [markdown]
# # Analisi dei dati italiani
# in questo file andrò ad analizzare i dati italiani di maggio 2019

# %% [markdown]
# ## Import utili

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import mysql.connector as sql

# %% [markdown]
# ## Connessione al database
#  Uso il metodo  **.fetchall** per la query Select : Ritorna una lista di tuple , se non ci sono tuple ritorna una lista vuota.

# %%
db_connection = sql.connect(host='localhost', database='kickstarter', user='root', password='password')
db_cursor = db_connection.cursor()

# %%
db_cursor.execute('SELECT * FROM dataset')
table_rows = db_cursor.fetchall()
df = pd.DataFrame(table_rows)
df
# Out:
#        0                                                  1      2   3   \
# 0       1  I would like to open a pastry shop, make a cha...     37  IT
# 1       9  We would like to revive the habit of shared br...    196  IT
# 2     228  Una campagna di fact-checking animati per rend...  12600  IT
# 3       1  A simple and complete app that allows speakers...      1  IT
# 4      20  Witchsummit is aproaching! Witches from all ov...   1310  IT
# ...   ...                                                ...    ...  ..
# 2052    3  I'd like to record a jazz cd inviting to play ...     34  IT
# 2053    1  A short family movie based on the novel "the g...      1  IT
# 2054    0  Un libro su coloro che ho amato, perduto e mai...      0  IT
# 2055    0  What is our dream? Do a huge Youtube film seri...      0  IT
# 2056    5  Realize the new computing revolution! Create t...     63  IT
#
#               4    5  6      7    8           9   ...  \
# ...

# %%
index='country'
n= dataset['country'].nunique()
country= dataset['country']
plt.hist(country,n)
