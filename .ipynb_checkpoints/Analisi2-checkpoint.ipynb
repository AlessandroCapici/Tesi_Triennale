# %% [markdown]
# # Analisi Di successo
# ### che tipo di obiettivo in termine monetario dovrebbe mettere un utente per avere una maggiore probabilita di successo?

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.io import sql
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:password@localhost/kickstarter')

# %%
query="select count(state) as count ,state from l0it group by state"
df=sql.read_sql_query(query,engine)
print(df)
df.plot(x='count',y='state',figsize = (10,10),kind='pie')
# Out:
#    count       state
# 0   2312    canceled
# 1  19334      failed
# 2   2767        live
# 3  10411  successful
# 4    139   suspended
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0770666d57cd> in <module>
#       2 df=sql.read_sql_query(query,engine)
#       3 print(df)
# ----> 4 df.plot(x='count',y='state',figsize = (10,10),kind='pie')
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#      62     plot_obj.draw()
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\plotting\_matplotlib\core.py in __init__(self, data, kind, **kwargs)
#    1505     def __init__(self, data, kind=None, **kwargs):
#    1506         data = data.fillna(value=0)
# -> 1507         if (data < 0).any().any():
#    1508             raise ValueError(f"{kind} doesn't allow negative values")
#    1509         MPLPlot.__init__(self, data, kind=kind, **kwargs)
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     237
#     238     elif is_object_dtype(lvalues.dtype):
# --> 239         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     240
#     241     else:
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
query="select * from l0 where state=1 or state=4"
df=sql.read_sql_query(query,engine)
df['log_goal']=np.log10(df['goal'])
df['log_goal'].plot.hist(bins = 35)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(x='log_goal',y='backers_count',kind='scatter')
# Out:
# <AxesSubplot:xlabel='log_goal', ylabel='backers_count'>

# %%
sns.lmplot(x = 'log_goal', y = 'backers_count', col ='state', data = df, fit_reg = False)

# %% [markdown]
# ### noto che il limite dell obiettivo per cui i donatori donano è 5 , che convertito dalla scala logaritmica diventa 10^5 che è il limite massimo di donazione, infatti nel output sottostante vedo che i progetti con tale limite superato di successo sono solo 11 su 1216

# %%
df[df['goal']>100000]['state'].value_counts()
# Out:
# 1    1205
# 4      11
# Name: state, dtype: int64

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x ='state', y = 'log_goal', data = df)
df.groupby('state')['goal'].median().T
# Out:
# state
# 1    10000.0
# 4     2999.0
# Name: goal, dtype: float64

# %% [markdown]
# #### in conclusione secondo i dati raccolti in questo dataset a livello di "obiettivo da raggiungere" i progetti di successo hanno una media intorno a 3000
