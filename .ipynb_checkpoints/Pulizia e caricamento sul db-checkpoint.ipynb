# %% [markdown]
# # Pulizia e Caricamento dati
# In questo file andrò a caricare il mio dataset dai file csv ,pulirlo da eventuali dati not well formed ed in seguito caricarli
# sul db,filtrando solo i dati italiani

# %% [markdown]
# ## Import Utili

# %%
import pandas as pd
import mysql.connector as sql
import json

# %% [markdown]
# ## Definisco funzioni per caricare e pulire i dati
# ### Ho varie funzioni :
#   - **readCsv** : leggo il csv
#   - **getCategory** : leggo solo la colonna category normalizzata visto che i record in quella colonna sono in formato json
#   - **getCreator** : leggo solo la colonna creator normalizzata visto che i record in quella colonna sono in formato json
#   - **getPhoto** : leggo solo la colonna photo normalizzata visto che i record in quella colonna sono in formato json
#   - **getLocation** : leggo solo la colonna location normalizzata visto che i record in quella colonna sono in formato json
#   - **getProfile** : leggo solo la colonna profile normalizzata visto che i record in quella colonna sono in formato json
#   - **getUrls** : leggo solo la colonna urls normalizzata visto che i record in quella colonna sono in formato json
#   - **besteffort_loads** : funzione che mi permette di caricare i json not well formed impostando valori non leggibili a null
#   - **merge** : Prendo in ingresso una DataFrame corrispondente a una colonna con i dati in formato json e la aggiungo al
#   - **filterByCountry** : Faccio un filtraggio delle righe per nazione
#   - **get** : Faccio un filtraggio delle righe per nazione
#   dataset iniziale

# %%
def readCsv(path):
    return pd.read_csv(path)

# %%
def getCategory(dataset):
    normalized_category=pd.json_normalize(dataset.category.apply(json.loads))
    normalized_category.columns=normalized_category.columns.map(lambda x: str(x) + '_category')
    return normalized_category

# %%
def besteffort_loads(obj):
    try:
        return json.loads(obj)
    except (TypeError, ValueError):
        return {}

# %%
def getCreator(dataset):
    normalized_creator=pd.json_normalize(dataset.creator.apply(besteffort_loads))
    normalized_creator.columns=normalized_creator.columns.map(lambda x: str(x) + '_creator')
    return normalized_creator

# %%
def getPhoto(dataset):
    normalized_Photo=pd.json_normalize(dataset.photo.apply(besteffort_loads))
    normalized_Photo.columns=normalized_Photo.columns.map(lambda x: str(x) + '_photo')
    return normalized_Photo

# %%
def getLocation(dataset):
    normalized_location=pd.json_normalize(dataset.location.apply(besteffort_loads))
    normalized_location.columns=normalized_location.columns.map(lambda x: str(x) + '_location')
    return normalized_location

# %%
def getProfile(dataset):
    normalized_profile=pd.json_normalize(dataset.profile.apply(besteffort_loads))
    normalized_profile.columns=normalized_profile.columns.map(lambda x: str(x) + '_profile')
    return normalized_profile

# %%
def getUrls(dataset):
    normalized_url=pd.json_normalize(dataset.urls.apply(besteffort_loads))
    normalized_url.columns=normalized_url.columns.map(lambda x: str(x) + '_url')
    return normalized_url

# %%
def merge(dataset,category,name):
    merged_data = pd.merge(dataset,category, left_index=True, right_index=True)
    del merged_data[name]
    return merged_data

# %%
def filterByCountry(dataset,country):
    return dataset.loc[dataset['country'] == country]

# %% [markdown]
# ## Pulisco il Dataset
#  Utilizzando le funzioni prima definite per caricare e pulire i dati di un Dataset

# %%
dataset=readCsv('csv\Kickstarter000.csv')
category= getCategory(dataset)
dataset= merge(dataset,category,'category')
creator= getCreator(dataset)
dataset= merge(dataset,creator,'creator')
location = getLocation(dataset)
dataset= merge(dataset,location,'location')
photo = getPhoto(dataset)
dataset= merge(dataset,photo,'photo')
profile = getProfile(dataset)
dataset= merge(dataset,profile,'profile')
urls = getUrls(dataset)
dataset= merge(dataset,urls,'urls')
dataset=filterByCountry(dataset,'IT')#perche non va se lo metto all inizio?(chiedere al prof)
dataset = dataset.applymap(str)
# Out:
#      backers_count                                              blurb  \
# 120              1  Vivi una magica avventura,scopri un'oscuro pas...
# 623              3  Arduino-based device that guides you into brea...
# 636             10  It's the 1st web-based controller developed in...
# 641             10                     The top of progressive thought
# 655              2  An Endless Game with a particularity: instead ...
# 744             21  A unique handmade set of plexiglass and wood l...
# 745             17  Master the art of negotiation with Dealer’s Li...
# 773              3                         Now it's easy to live easy
# 881              8  We want to bring back the beauty of a 18th cen...
# 1011             1  A documentary movie tells the story of a secre...
# 1190           667  Custom playing cards inspired by the Universe....
# 1212             1  BADASS: powerful vocal, killer distorted bass,...
# 1228           136  La terza edizione del Calendario d'arte tolkie...
# 1230             0  Creating an app for our daily devices that all...
# 1298             2  Ulysse is an app that allows solo travelers to...
# 1357           452  Eco-friendly, giant building blocks to fire up...
# 1387             2            2nd part of the trilogy! - The Return -
# 1622             3  The project was created to promote a unique an...
# 1718             2  2 Weeks of Double exposure Photo Exibition in ...
# 1796            59  An easy to use desktop foam cutter. Give vent ...
# 1917             3  THE ITALIAN VINTAGE MOPED - Help us built the ...
# 2050            13  FlowerCube transforms every Monitor, TV, old C...
# 2217             2  A new concept to show & introduce the world of...
# 2257             9            An app to discover people's social life
# 2267            11  HAPPY MORNING. Time to Change! To Clean, Safe ...
# 2359             3  I create bags that are so beautiful you'll wan...
# 2433            28  The first navigation system, usable by each me...
# 2440            16  ARTONIGHT? is an art exhibition for those who ...
# 2470             1  De amicis Roma is the sex in a airplane betwee...
# 2728           140                               Nandha Strikes Again
# 2841            16  The ultimate technological Shirt: 100% cotton,...
# 2884             0  It’s original, fashion and unique, Ohyear is t...
# 2971             2  Design business cards for different people. Ea...
# 3060            37  A game of intrigue, strategy and perfidy. And ...
# 3107           107  HeresyLab - The campaign is to release the STL...
# 3297            24  "Climb over the Horizon" is a sci-fi concept a...
# 3535             0  After more than 25 years in music field, I'm g...
# 3652             3       Vera is a fact checking app/site of any news
# 3657            58  La Dama Nera: lussuria e tenebre nella nuova a...
# 3737           571  360LOCK is a fully customizable smart padlock ...
# 3747             7  Benidorm is a project that was supposed to hel...
#
#      converted_pledged_amount country  created_at currency currency_symbol  \
# 120                         1      IT  1462016360      EUR               €
# 623                        11      IT  1552300032      EUR               €
# 636                       788      IT  1487082030      EUR               €
# 641                       893      IT  1537631407      EUR               €
# 655                         6      IT  1538787537      EUR               €
# 744                      1173      IT  1535359957      EUR               €
# 745                       815      IT  1475499883      EUR               €
# 773                        85      IT  1554103984      EUR               €
# 881                       174      IT  1539685546      EUR               €
# 1011                        1      IT  1485158842      EUR               €
# 1190                    57267      IT  1546363343      EUR               €
# 1212                       33      IT  1462889899      EUR               €
# 1228                     6974      IT  1535382618      EUR               €
# 1230                        0      IT  1503147956      EUR               €
# 1298                        3      IT  1499431301      EUR               €
# 1357                    43561      IT  1471351048      EUR               €
# 1387                       17      IT  1506323237      EUR               €
# 1622                      650      IT  1481893545      EUR               €
# 1718                       81      IT  1441892911      EUR               €
# 1796                    20324      IT  1487860006      EUR               €
# 1917                       46      IT  1498653229      EUR               €
# 2050                     1208      IT  1452187856      EUR               €
# 2217                        2      IT  1493220378      EUR               €
# 2257                     3669      IT  1500647387      EUR               €
# 2267                      384      IT  1444711782      EUR               €
# 2359                      127      IT  1514039489      EUR               €
# 2433                     5505      IT  1470756414      EUR               €
# 2440                      639      IT  1523027037      EUR               €
# 2470                        1      IT  1555026805      EUR               €
# 2728                     8745      IT  1544463752      EUR               €
# 2841                     3155      IT  1523630250      EUR               €
# 2884                        0      IT  1472552035      EUR               €
# 2971                        6      IT  1540817510      EUR               €
# 3060                     4766      IT  1539088187      EUR               €
# 3107                     6174      IT  1533475683      EUR               €
# 3297                      415      IT  1552229450      EUR               €
# 3535                        0      IT  1486062644      EUR               €
# 3652                        4      IT  1529598977      EUR               €
# 3657                     2977      IT  1538496466      EUR               €
# 3737                    50490      IT  1532353422      EUR               €
# 3747                       42      IT  1519260841      EUR               €
#
#      currency_trailing_code current_currency    deadline  ...  \
# 120                   False              USD  1467202823  ...
# 623                   False              USD  1555012857  ...
# 636                   False              USD  1490363800  ...
# 641                   False              USD  1544049583  ...
# 655                   False              USD  1543978715  ...
# 744                   False              USD  1538408461  ...
# 745                   False              USD  1479758400  ...
# 773                   False              USD  1559242643  ...
# 881                   False              USD  1547568985  ...
# 1011                  False              USD  1494782024  ...
# 1190                  False              USD  1551600000  ...
# 1212                  False              USD  1477043848  ...
# 1228                  False              USD  1539429530  ...
# 1230                  False              USD  1506023134  ...
# 1298                  False              USD  1504617173  ...
# 1357                  False              USD  1476182405  ...
# 1387                  False              USD  1512128968  ...
# 1622                  False              USD  1484681459  ...
# 1718                  False              USD  1445085581  ...
# 1796                  False              USD  1494532480  ...
# 1917                  False              USD  1517733425  ...
# 2050                  False              USD  1459631474  ...
# 2217                  False              USD  1499816328  ...
# 2257                  False              USD  1503009355  ...
# 2267                  False              USD  1448653959  ...
# 2359                  False              USD  1522061791  ...
# 2433                  False              USD  1477731463  ...
# 2440                  False              USD  1526418584  ...
# 2470                  False              USD  1558645889  ...
# 2728                  False              USD  1553356616  ...
# 2841                  False              USD  1528461567  ...
# 2884                  False              USD  1475310825  ...
# 2971                  False              USD  1541977200  ...
# 3060                  False              USD  1544224500  ...
# 3107                  False              USD  1535050800  ...
# 3297                  False              USD  1559903633  ...
# 3535                  False              USD  1489337536  ...
# 3652                  False              USD  1532826842  ...
# 3657                  False              USD  1545991264  ...
# 3737                  False              USD  1537285573  ...
# 3747                  False              USD  1525797252  ...
#
#      feature_image_attributes.image_urls.baseball_card_profile  \
# 120   https://ksr-ugc.imgix.net/assets/012/441/677/d...
# 623   https://ksr-ugc.imgix.net/assets/024/376/496/3...
# 636   https://ksr-ugc.imgix.net/assets/015/551/532/3...
# 641   https://ksr-ugc.imgix.net/assets/023/129/669/b...
# 655   https://ksr-ugc.imgix.net/assets/022/796/715/0...
# 2050  https://www.kickstarter.com/projects/190697768...          nan
# 2217  https://www.kickstarter.com/projects/976436033...          nan
# 2257  https://www.kickstarter.com/projects/100692833...          nan
# 2267  https://www.kickstarter.com/projects/39184522/...          nan
# 2359  https://www.kickstarter.com/projects/393983236...          nan
# 2433  https://www.kickstarter.com/projects/101837421...          nan
# 2440  https://www.kickstarter.com/projects/294875279...          nan
# 2470  https://www.kickstarter.com/projects/926534486...          nan
# 2728  https://www.kickstarter.com/projects/140908428...          nan
# 2841  https://www.kickstarter.com/projects/breezshir...          nan
# 2884  https://www.kickstarter.com/projects/292562771...          nan
# 2971  https://www.kickstarter.com/projects/graphicby...          nan
# 3060  https://www.kickstarter.com/projects/116287758...          nan
# 3107  https://www.kickstarter.com/projects/heresylab...          nan
# 3297  https://www.kickstarter.com/projects/nicolasti...          nan
# 3535  https://www.kickstarter.com/projects/jklloyd/j...          nan
# 3652  https://www.kickstarter.com/projects/mariuskal...          nan
# 3657  https://www.kickstarter.com/projects/isolailly...          nan
# 3737  https://www.kickstarter.com/projects/168661261...          nan
# 3747  https://www.kickstarter.com/projects/972178148...          nan
#
#      api.message_creator_url web.message_creator_url
# 120                      nan                     nan
# 623                      nan                     nan
# 636                      nan                     nan
# 641                      nan                     nan
# 655                      nan                     nan
# 744                      nan                     nan
# 745                      nan                     nan
# 773                      nan                     nan
# 881                      nan                     nan
# 1011                     nan                     nan
# 1190                     nan                     nan
# 1212                     nan                     nan
# 1228                     nan                     nan
# 1230                     nan                     nan
# 1298                     nan                     nan
# 1357                     nan                     nan
# 1387                     nan                     nan
# 1622                     nan                     nan
# 1718                     nan                     nan
# 1796                     nan                     nan
# 1917                     nan                     nan
# 2050                     nan                     nan
# 2217                     nan                     nan
# 2257                     nan                     nan
# 2267                     nan                     nan
# 2359                     nan                     nan
# 2433                     nan                     nan
# 2440                     nan                     nan
# 2470                     nan                     nan
# 2728                     nan                     nan
# 2841                     nan                     nan
# 2884                     nan                     nan
# 2971                     nan                     nan
# 3060                     nan                     nan
# 3107                     nan                     nan
# 3297                     nan                     nan
# 3535                     nan                     nan
# 3652                     nan                     nan
# 3657                     nan                     nan
# 3737                     nan                     nan
# 3747                     nan                     nan
#
# [41 rows x 96 columns]

# %% [markdown]
# ## Connessione al DB
# Uso msql.connector , libreria ufficiale di mysql.
#
# Ha vari metodi tra cui:
#    - **.connect**: Crea una connessione col db.
#    - **.cursor**: Istanzia un oggetto che può eseguire un operazione sul db(come lo statment in java).
#    - **.execute**: Esegue una query sul db.

# %%
# mi connetto al db
db_connection = sql.connect(host='localhost', database='kickstarter', user='root', password='password')
db_cursor = db_connection.cursor()

# %% [markdown]
# ## Creo la tabella nel db
# Creo la tabella dataset dentro il database kickstarter e imposto il campo id come chiave primaria

# %%
#creo la stringa con tutte le colonne e creo la tabella sul db
s=''
for c in dataset.columns:
    c=c.replace(".","_")
    if c=='web_message_creator_url':
        s=s+c+' VARCHAR(255)'
    else:
        s=s+c+' VARCHAR(255),'
db_cursor.execute("DROP TABLE IF EXISTS dataset")        
db_cursor.execute("CREATE TABLE dataset ("+s+")")
db_cursor.execute("ALTER TABLE kickstarter.dataset CHANGE COLUMN id id VARCHAR(255) NOT NULL ,ADD PRIMARY KEY (`id`)")

# %%
#creo la lista delle colonne per la insert into 
s=''
count=0
for c in dataset.columns:
    count=count+1
    c=c.replace(".","_")
    if c=='web_message_creator_url':
        s=s+c
    else:
        s=s+c+','
values="%s,"*(count-1)+"%s"

# %% [markdown]
# ## Caricamento tuple del dataset italiano
# In questa cella ciclo su tutti i file csv presenti, pulisco il dataset e eseguo delle insert into sul database , ignoro query non andate a buon fine ed evito di caricare la tupla(chiedere al prof)

# %%
for i in range (0,56):
    file='csv\Kickstarter0'
    if i<=9:
        file=file+'0'+str(i)+'.csv'
    else:
        file=file+str(i)+'.csv'
    dataset=readCsv(file)
    print(file)
    category= getCategory(dataset)
    dataset= merge(dataset,category,'category')
    creator= getCreator(dataset)
    dataset= merge(dataset,creator,'creator')
    location = getLocation(dataset)
    dataset= merge(dataset,location,'location')
    photo = getPhoto(dataset)
    dataset= merge(dataset,photo,'photo')
    profile = getProfile(dataset)
    dataset= merge(dataset,profile,'profile')
    urls = getUrls(dataset)
    dataset= merge(dataset,urls,'urls')
    dataset=filterByCountry(dataset,'IT')
    dataset = dataset.applymap(str)
    for i,row in dataset.iterrows():
        query="INSERT INTO `dataset` (" +s+ ") VALUES (" +values+ ")"
        try:
            db_cursor.execute(query,tuple(row))
            db_connection.commit()
        except :
            continue
# Out:
# csv\Kickstarter000.csv
# csv\Kickstarter001.csv
# csv\Kickstarter002.csv
# csv\Kickstarter003.csv
# csv\Kickstarter004.csv
# csv\Kickstarter005.csv
# csv\Kickstarter006.csv
# csv\Kickstarter007.csv
# csv\Kickstarter008.csv
# csv\Kickstarter009.csv
# csv\Kickstarter010.csv
# csv\Kickstarter011.csv
# csv\Kickstarter012.csv
# csv\Kickstarter013.csv
# csv\Kickstarter014.csv
# csv\Kickstarter015.csv
# csv\Kickstarter016.csv
# csv\Kickstarter017.csv
# csv\Kickstarter018.csv
# csv\Kickstarter019.csv
# csv\Kickstarter020.csv
# csv\Kickstarter021.csv
# csv\Kickstarter022.csv
# csv\Kickstarter023.csv
# csv\Kickstarter024.csv
# csv\Kickstarter025.csv
# csv\Kickstarter026.csv
# csv\Kickstarter027.csv
# csv\Kickstarter028.csv
# csv\Kickstarter029.csv
# csv\Kickstarter030.csv
# csv\Kickstarter031.csv
# csv\Kickstarter032.csv
# csv\Kickstarter033.csv
# csv\Kickstarter034.csv
# csv\Kickstarter035.csv
# csv\Kickstarter036.csv
# csv\Kickstarter037.csv
# csv\Kickstarter038.csv
# csv\Kickstarter039.csv
# csv\Kickstarter040.csv
# csv\Kickstarter041.csv
# csv\Kickstarter042.csv
# csv\Kickstarter043.csv
# csv\Kickstarter044.csv
# csv\Kickstarter045.csv
# csv\Kickstarter046.csv
# csv\Kickstarter047.csv
# csv\Kickstarter048.csv
# csv\Kickstarter049.csv
# csv\Kickstarter050.csv
# csv\Kickstarter051.csv
# csv\Kickstarter052.csv
# csv\Kickstarter053.csv
# csv\Kickstarter054.csv
# csv\Kickstarter055.csv
