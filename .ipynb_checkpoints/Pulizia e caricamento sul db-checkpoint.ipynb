# %% [markdown]
# # Pulizia e Caricamento dati
# In questo file andrò a caricare il mio dataset dai file csv ,pulirlo da eventuali dati not well formed ed in seguito caricarli
# sul db,filtrando solo i dati italiani

# %% [markdown]
# ## Import Utili

# %%
import pandas as pd
from pandas.io import sql
from sqlalchemy import create_engine
import json

# %% [markdown]
# ## Definisco funzioni per caricare e pulire i dati
# ### Ho varie funzioni :
#   - **getCategory** : leggo solo la colonna category normalizzata visto che i record in quella colonna sono in formato json
#   - **getCreator** : leggo solo la colonna creator normalizzata visto che i record in quella colonna sono in formato json
#   - **getPhoto** : leggo solo la colonna photo normalizzata visto che i record in quella colonna sono in formato json
#   - **getLocation** : leggo solo la colonna location normalizzata visto che i record in quella colonna sono in formato json
#   - **getProfile** : leggo solo la colonna profile normalizzata visto che i record in quella colonna sono in formato json
#   - **getUrls** : leggo solo la colonna urls normalizzata visto che i record in quella colonna sono in formato json
#   - **besteffort_loads** : funzione che mi permette di caricare i json not well formed impostando valori non leggibili a null
#   - **merge** : Prendo in ingresso una DataFrame corrispondente a una colonna con i dati in formato json e la aggiungo al
#   dataset

# %%
def getCategory(dataset):
    normalized_category=pd.json_normalize(dataset.category.apply(json.loads))
    normalized_category.columns=normalized_category.columns.map(lambda x: str(x) + '_category')
    return normalized_category

# %%
def besteffort_loads(obj):
    try:
        return json.loads(obj)
    except (TypeError, ValueError):
        return {}

# %%
def getCreator(dataset):
    normalized_creator=pd.json_normalize(dataset.creator.apply(besteffort_loads))
    normalized_creator.columns=normalized_creator.columns.map(lambda x: str(x) + '_creator')
    return normalized_creator

# %%
def getPhoto(dataset):
    normalized_Photo=pd.json_normalize(dataset.photo.apply(besteffort_loads))
    normalized_Photo.columns=normalized_Photo.columns.map(lambda x: str(x) + '_photo')
    return normalized_Photo

# %%
def getLocation(dataset):
    normalized_location=pd.json_normalize(dataset.location.apply(besteffort_loads))
    normalized_location.columns=normalized_location.columns.map(lambda x: str(x) + '_location')
    return normalized_location

# %%
def getProfile(dataset):
    normalized_profile=pd.json_normalize(dataset.profile.apply(besteffort_loads))
    normalized_profile.columns=normalized_profile.columns.map(lambda x: str(x) + '_profile')
    return normalized_profile

# %%
def getUrls(dataset):
    normalized_url=pd.json_normalize(dataset.urls.apply(besteffort_loads))
    normalized_url.columns=normalized_url.columns.map(lambda x: str(x) + '_url')
    return normalized_url

# %%
def merge(dataset,category,name):
    merged_data = pd.merge(dataset,category, left_index=True, right_index=True)
    del merged_data[name]
    return merged_data

# %% [markdown]
# ## Connessione al DB
# Uso create_engine per creare la connessione
#
# Ha un parametro dove bisogna specificare:
#    - **User**
#    - **Password**
#    - **Host**
#    - **Schema**

# %%
engine = create_engine('mysql+pymysql://root:password@localhost/kickstarter?charset=utf8')

# %% [markdown]
# ## Caricamento tuple del dataset italiano
# In questa cella ciclo su tutti i file csv presenti, pulisco il dataset e eseguola conversione in sql (funzionalita di pandas) , ignoro query non andate a buon fine

# %%
for year in range (2018,2020):
    print(year)
    for month in range (1,13):
        print(month)
        for i in range (1,59):
            file='../csv/'+str(year)+'/'+str(month)+'/kickstarter0'
            if i<=9:
                file=file+'0'+str(i)+'.csv'
            else:
                file=file+str(i)+'.csv'
            try:
                dataset=pd.read_csv(file)
            except:
                continue
            category= getCategory(dataset)
            dataset= merge(dataset,category,'category')
            location = getLocation(dataset)
            dataset= merge(dataset,location,'location')
            photo = getPhoto(dataset)
            dataset= merge(dataset,photo,'photo')
            del dataset['urls']
            del dataset['creator']
            del dataset['profile']
            dataset=dataset.loc[dataset['country'] == 'GB']
            try:
                if ((year== 2018) and (month== 1) and (i==1)) :
                    print('solo ora')
                    print(dataset['blurb'][96])
                    sql.to_sql(dataset,con=engine,name='l0e',if_exists='replace')
                else :
                    sql.to_sql(dataset,con=engine,name='l0e',if_exists='append' )
            except Exception as e:
                print(e)
                continue
# Out:
# 2018
# 1
# solo ora
# 96
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC4\\xBCga' for column 'state_location' at row 24")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, parent_id_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(parent_id_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 100, 'backers_count': 21, 'blurb': 'Art exhibition created by students of UWTSD looking for generous people to sponsor to help us create our final degree show.', 'converted_pledged_amount': 766, 'country': 'GB', 'created_at': 1425996817, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1429520460, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 500.0, 'id': 498440578, 'is_starrable': 0, 'launched_at': 1426782879, 'name': 'UWTSD Celf a Dylunio Degree show 2015', 'pledged': 512.0, 'slug': 'uwtsd-celf-a-dylunio-degree-show-2015', 'source_url': 'https://www.kickstarter.com/discover/categories/art/mixed%20media', 'spotlight': 1, 'staff_pick': 0, 'state': 'successful', 'state_changed_at': 1429520462, 'static_usd_rate': 1.47589059, 'usd_pledged': 755.65598208, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16760235, 'parent_id_category': 1, 'name_category': 'Mixed Media', 'id_category': 54, 'position_category': 6, 'slug_category': 'art/mixed media', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/art/mixed%20media', 'country_location': 'GB', 'name_location': 'Carmarthen', 'displayable_name_location': 'Carmarthen, UK', 'short_name_location': 'Carmarthen, UK', 'id_location': 15208.0, 'state_location': 'Wales', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'carmarthen-gb', 'localized_name_location': 'Carmarthen', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/carmarthen-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/carmarthen-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515876529.e97c002963c3496ec795238abbfa7d9b4a8b4dfd&woe_id=15208', 'small_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=160&h=90&fit=crop&v=1463728697&auto=format&q=92&s=bcdbc8c7cf1a13e34a0ecce0e5fb5305', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=48&h=27&fit=crop&v=1463728697&auto=format&q=92&s=0be1fee3c297070778a70e441e2181ec', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=1024&h=576&fit=crop&v=1463728697&auto=format&q=92&s=8fcb5e9a3f7c9044dda8eedbd2a50cfd', 'med_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=272&h=153&fit=crop&v=1463728697&auto=format&q=92&s=d96e68c67b74e1f853925baff756fdce', 'key_photo': 'assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=1552&h=873&fit=crop&v=1463728697&auto=format&q=92&s=951ad79fee7949d4e1033be6c4bac683', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=352&h=198&fit=crop&v=1463728697&auto=format&q=92&s=3199351d419d4c462aed674160af1f72', 'full_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=560&h=315&fit=crop&v=1463728697&auto=format&q=92&s=458256893cdbd50eb8faa45eabfe5fb4', 'little_photo': 'https://ksr-ugc.imgix.net/assets/012/064/758/bdc472ebd65fa85ae3fbc7d82efd1e78_original.png?crop=faces&w=208&h=117&fit=crop&v=1463728697&auto=format&q=92&s=e6fe4fbe2a0314f21bc35052689c1742'}, {'index': 107, 'backers_count': 52, 'blurb': 'The Camberwell MA Printmaking 2015 show is fast-approaching, and we need help funding it', 'converted_pledged_amount': 2030, 'country': 'GB', 'created_at': 1427293339, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1430390438, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xE3\\x80\\x8EEdi...' for column 'blurb' at row 4")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, parent_id_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(parent_id_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 270, 'backers_count': 0, 'blurb': 'Alldifferenttalents is a website which allows aspiring artists to showcase their talents to the world.', 'converted_pledged_amount': 0, 'country': 'GB', 'created_at': 1506103033, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1506984362, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 5000.0, 'id': 399884959, 'is_starrable': 0, 'launched_at': 1506379562, 'name': 'Alldifferenttalents (Canceled)', 'pledged': 0.0, 'slug': 'alldifferenttalents', 'source_url': 'https://www.kickstarter.com/discover/categories/art/performance%20art', 'spotlight': 0, 'staff_pick': 0, 'state': 'canceled', 'state_changed_at': 1506551683, 'static_usd_rate': 1.34934921, 'usd_pledged': 0.0, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16760235, 'parent_id_category': 1, 'name_category': 'Performance Art', 'id_category': 24, 'position_category': 8, 'slug_category': 'art/performance art', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/art/performance%20art', 'country_location': 'GB', 'name_location': 'Greater Manchester', 'displayable_name_location': 'Greater Manchester, UK', 'short_name_location': 'Greater Manchester, UK', 'id_location': 12602158.0, 'state_location': 'England', 'type_location': 'County', 'is_root_location': 0, 'slug_location': 'greater-manchester-gb', 'localized_name_location': 'Greater Manchester', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/greater-manchester-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/greater-manchester-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515876024.2379465c2ac66f6da38476e1d842ae27c25df470&woe_id=12602158', 'small_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=160&h=90&fit=crop&v=1506103763&auto=format&q=92&s=ab521ea99559af0337220216b5b6d2d6', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=48&h=27&fit=crop&v=1506103763&auto=format&q=92&s=6035e89edee0d1c7a93225f0ad5be57c', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=1024&h=576&fit=crop&v=1506103763&auto=format&q=92&s=6cd9e17d87d7d4911a0b9de0b1d5611b', 'med_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=272&h=153&fit=crop&v=1506103763&auto=format&q=92&s=3724692c0c6b30e6f611715611a9d537', 'key_photo': 'assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=1552&h=873&fit=crop&v=1506103763&auto=format&q=92&s=5eed2f6acbffd413252147b4628614ab', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=352&h=198&fit=crop&v=1506103763&auto=format&q=92&s=55e882740d9272ae57d1293681dbd23d', 'full_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=560&h=315&fit=crop&v=1506103763&auto=format&q=92&s=6e75f3649cc1d4eed4f901007629a44a', 'little_photo': 'https://ksr-ugc.imgix.net/assets/018/440/774/1c64b05eca0acc82c0750e2c4e4c4545_original.jpg?crop=faces&w=208&h=117&fit=crop&v=1506103763&auto=format&q=92&s=ce98b675c3799415558a7b3ae15eb220'}, {'index': 298, 'backers_count': 0, 'blurb': 'The Worlds FIRST Mobile Dinosaur Zoo bringing Dinosaur education, entertainment/comedy and promotional work to life.  pledge Today', 'converted_pledged_amount': 0, 'country': 'GB', 'created_at': 1454430527, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1457182174, ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC8\\x97z - ...' for column 'name' at row 77")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, parent_id_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(parent_id_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 308, 'backers_count': 1, 'blurb': 'I want to make a massive pile of money.', 'converted_pledged_amount': 1, 'country': 'GB', 'created_at': 1431369500, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1434056436, 'disable_communication': 1, 'fx_rate': 1.35496949, 'goal': 50.0, 'id': 2109651528, 'is_starrable': 0, 'launched_at': 1431464436, 'name': 'Money please. (Suspended)', 'pledged': 1.0, 'slug': 'money-please', 'source_url': 'https://www.kickstarter.com/discover/categories/art/sculpture', 'spotlight': 0, 'staff_pick': 0, 'state': 'suspended', 'state_changed_at': 1431468134, 'static_usd_rate': 1.54235777, 'usd_pledged': 1.54235777, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16760235, 'parent_id_category': 1.0, 'name_category': 'Sculpture', 'id_category': 25, 'position_category': 10, 'slug_category': 'art/sculpture', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/art/sculpture', 'country_location': 'GB', 'name_location': 'Wales', 'displayable_name_location': 'Wales, UK', 'short_name_location': 'Wales, UK', 'id_location': 38978.0, 'state_location': 'England', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'wales-gb', 'localized_name_location': 'Wales', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/wales-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/wales-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515876030.121f35bd5b8f5d28cc240694ccd59c2e9c439faa&woe_id=38978', 'small_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=160&h=90&fit=crop&v=1463738216&auto=format&q=92&s=f02402222fc7c5de04a86ee5e178117f', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=48&h=27&fit=crop&v=1463738216&auto=format&q=92&s=c8a71d1550174ae5766bc71206c17f12', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=1024&h=576&fit=crop&v=1463738216&auto=format&q=92&s=6bfded478104d9c7472800548c0c2579', 'med_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=272&h=153&fit=crop&v=1463738216&auto=format&q=92&s=9896566d7fed0d804f8a7dfac616486b', 'key_photo': 'assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=1552&h=873&fit=crop&v=1463738216&auto=format&q=92&s=3442237331b7384672e6dcfd4bed9c21', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=352&h=198&fit=crop&v=1463738216&auto=format&q=92&s=083ee9848fd6c34f15983a53998697e4', 'full_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=560&h=315&fit=crop&v=1463738216&auto=format&q=92&s=beb12efc106e279cb072c93082dd8a72', 'little_photo': 'https://ksr-ugc.imgix.net/assets/012/134/802/4f64e8e8db1a8eec44bfa560e0f38c2f_original.JPG?crop=faces&w=208&h=117&fit=crop&v=1463738216&auto=format&q=92&s=ff0e97cfd5dbb12f3a1ca9a45ffad17b'}, {'index': 314, 'backers_count': 0, 'blurb': 'Victor Creations is a prop and theming business breaking into the UK market. Body parts, bespoke pieces, sculpting and more.', 'converted_pledged_amount': 0, 'country': 'GB', 'created_at': 1494849880, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1498043593, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 2378.0, 'id': 1581266060, 'is_starrable': 0, 'launched_at': 1495451593, 'name': 'Victor Creations (Canceled)', 'pledged': 0.0, 'slug': 'vi ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC5\\x8Dnen ...' for column 'blurb' at row 315")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, parent_id_category, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(parent_id_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 28, 'backers_count': 50, 'blurb': 'Creepy Scarlett Vs. Trixie Von comic book.', 'converted_pledged_amount': 1484, 'country': 'GB', 'created_at': 1377262023, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1381430814, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 500, 'id': 363826366, 'is_starrable': 0, 'launched_at': 1377542814, 'name': 'Creepy Scarlett Vs. Trixie Von', 'pledged': 932.0, 'slug': 'creepy-scarlett-vs-trixie-von', 'source_url': 'https://www.kickstarter.com/discover/categories/comics', 'spotlight': 1, 'staff_pick': 0, 'state': 'successful', 'state_changed_at': 1381430814, 'static_usd_rate': 1.55698972, 'usd_pledged': 1451.11441904, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16776056, 'name_category': 'Comics', 'id_category': 3, 'position_category': 2, 'slug_category': 'comics', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/comics', 'parent_id_category': None, 'country_location': 'GB', 'name_location': 'Dundee', 'displayable_name_location': 'Dundee, UK', 'short_name_location': 'Dundee, UK', 'id_location': 18637, 'state_location': 'Scotland', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'dundee-gb', 'localized_name_location': 'Dundee', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/dundee-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/dundee-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515876067.714ee0f11a67a9395408347bb7eb3ba9b8c86dea&woe_id=18637', 'small_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=160&h=90&fit=crop&v=1463684583&auto=format&q=92&s=2a94ec6891b8b85f2c9332584662ddc9', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=48&h=27&fit=crop&v=1463684583&auto=format&q=92&s=2e24c4be38abd00a3f2c0b29898f868a', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=1024&h=576&fit=crop&v=1463684583&auto=format&q=92&s=6f0430cf0ff390cb6b4ad00d699d6d6d', 'med_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=272&h=153&fit=crop&v=1463684583&auto=format&q=92&s=2aa3b90e632d69354e6a042f10d2fa2a', 'key_photo': 'assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=1552&h=873&fit=crop&v=1463684583&auto=format&q=92&s=1bb1e59930ec28c7b6228df96771d093', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=352&h=198&fit=crop&v=1463684583&auto=format&q=92&s=85965244ea0ce89512c32c2da7933599', 'full_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=560&h=315&fit=crop&v=1463684583&auto=format&q=92&s=e8f3574338e5bb9c66a54ff2b5c84ed6', 'little_photo': 'https://ksr-ugc.imgix.net/assets/011/567/822/817ea268e5ca440239fa1b70d5991558_original.jpg?crop=faces&w=208&h=117&fit=crop&v=1463684583&auto=format&q=92&s=710f12a90f6cbfb2763a43a5f9a0a3ec'}, {'index': 43, 'backers_count': 99, 'blurb': 'An experimental sequential work created as a project in finding a path through depression in comic form. Kore is my rehab.', 'converted_pledged_amount': 3286, 'country': 'GB', 'created_at': 1376627273, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1379584348, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 350, 'id': 479316631, 'is_starrable': 0, 'launched_at': 1376992348, 'name': 'Kore', 'pledged': 2037.0, 'slug': 'kore', 'sour ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xE2\\x99\\xA5 Ju...' for column 'blurb' at row 307")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, parent_id_category, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(parent_id_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 7, 'backers_count': 74, 'blurb': 'Over 180 pages of Zombear ass kicking, brightly coloured, high octane action, and Teddy bear related puns..', 'converted_pledged_amount': 5588, 'country': 'GB', 'created_at': 1405537266, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1412238605, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 3000, 'id': 1557461907, 'is_starrable': 0, 'launched_at': 1409646605, 'name': 'Bearlands: Zombie Bears - Season One Collected', 'pledged': 3448.25, 'slug': 'zombie-bears-bearlands-season-one', 'source_url': 'https://www.kickstarter.com/discover/categories/comics', 'spotlight': 1, 'staff_pick': 0, 'state': 'successful', 'state_changed_at': 1412238612, 'static_usd_rate': 1.65936821, 'usd_pledged': 5721.9164301325, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16776056, 'name_category': 'Comic Books', 'id_category': 250, 'position_category': 2, 'slug_category': 'comics/comic books', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/comics/comic%20books', 'parent_id_category': 3.0, 'country_location': 'GB', 'name_location': 'London', 'displayable_name_location': 'London, UK', 'short_name_location': 'London, UK', 'id_location': 44418.0, 'state_location': 'England', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'london-gb', 'localized_name_location': 'London', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/london-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/london-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515876019.2763bb82e0e0304ab726e1510e4bbf8a67fcccfd&woe_id=44418', 'small_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=160&h=90&fit=crop&v=1463694732&auto=format&q=92&s=0ceb62e6bdb64227797d03812dde01b7', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=48&h=27&fit=crop&v=1463694732&auto=format&q=92&s=4f3abff84730c6673894f0d67eb98bbb', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=1024&h=576&fit=crop&v=1463694732&auto=format&q=92&s=ae1264e6949d1c70aa2f9eeb01ead0c1', 'med_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=272&h=153&fit=crop&v=1463694732&auto=format&q=92&s=0348f03af9e78a4175319539513133a9', 'key_photo': 'assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=1552&h=873&fit=crop&v=1463694732&auto=format&q=92&s=0c698e97f730fcb314dd3959f5626e54', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=352&h=198&fit=crop&v=1463694732&auto=format&q=92&s=da439aa4fd281846af956499e069cfe1', 'full_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=560&h=315&fit=crop&v=1463694732&auto=format&q=92&s=4a8b0cf3d701065496c6dc3e33b1eb5a', 'little_photo': 'https://ksr-ugc.imgix.net/assets/011/788/925/d0bf4d0ac029a35b17167adb12863252_original.jpg?crop=faces&w=208&h=117&fit=crop&v=1463694732&auto=format&q=92&s=7ba83d802ba9c93c2a550e0f14d3033f'}, {'index': 24, 'backers_count': 302, 'blurb': 'Orcs, elves and fire summons running a tea shop in modern day Cardiff… what could go wrong?', 'converted_pledged_amount': 4464, 'country': 'GB', 'created_at': 1498776454, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1501264800, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 800, 'id': 2027821616, 'is_star ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xE2\\x99\\xA5 Bu...' for column 'name' at row 103")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, parent_id_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(parent_id_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 3, 'backers_count': 2, 'blurb': 'Create the perfect wedding with TheTrademark. We have a range of gorgeous products to inspire your wedding styling whatever your theme.', 'converted_pledged_amount': 271, 'country': 'GB', 'created_at': 1459709256, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1462367832, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 1800, 'id': 1611312762, 'is_starrable': 0, 'launched_at': 1459775832, 'name': 'Wedding gift - Custom wooden doll', 'pledged': 187.0, 'slug': 'wedding-gift-custom-wooden-doll', 'source_url': 'https://www.kickstarter.com/discover/categories/crafts/diy', 'spotlight': 0, 'staff_pick': 0, 'state': 'failed', 'state_changed_at': 1462367832, 'static_usd_rate': 1.42289206, 'usd_pledged': 266.08081522, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16744876, 'parent_id_category': 26.0, 'name_category': 'DIY', 'id_category': 345, 'position_category': 3, 'slug_category': 'crafts/diy', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/crafts/diy', 'country_location': 'GB', 'name_location': 'Salford', 'displayable_name_location': 'Salford, UK', 'short_name_location': 'Salford, UK', 'id_location': 33887.0, 'state_location': 'England', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'salford-salford-metropolitan-borough-gb', 'localized_name_location': 'Salford', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/salford-salford-metropolitan-borough-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/salford-salford-metropolitan-borough-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515870099.c253c169ac934bec186d43fda8e782ecd0aa80d1&woe_id=33887', 'small_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=160&h=90&fit=crop&v=1463760405&auto=format&q=92&s=79510be40b01e5ac4d6f41a52c49e418', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=48&h=27&fit=crop&v=1463760405&auto=format&q=92&s=0e9fa153130abf555d6f644c77a2b7f1', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=1024&h=576&fit=crop&v=1463760405&auto=format&q=92&s=243bc1f9ff8d223fec8b36f62bac226b', 'med_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=272&h=153&fit=crop&v=1463760405&auto=format&q=92&s=3398ec86fc83cfb8db627eaaf5992679', 'key_photo': 'assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=1552&h=873&fit=crop&v=1463760405&auto=format&q=92&s=fba7c7695453f49be47114861faac213', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=352&h=198&fit=crop&v=1463760405&auto=format&q=92&s=ad3b42395e8280095f8a6241077d48af', 'full_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=560&h=315&fit=crop&v=1463760405&auto=format&q=92&s=a8572eef95b0c76872e01417723fd6db', 'little_photo': 'https://ksr-ugc.imgix.net/assets/012/421/200/3da0c3d792d3853b556093b17033cb8f_original.jpg?crop=faces&w=208&h=117&fit=crop&v=1463760405&auto=format&q=92&s=18b433221582357fdd9b0a93d7cba722'}, {'index': 29, 'backers_count': 5, 'blurb': 'A winter subscription service to banish away those long British winter days, with a teddy or two, or six!', 'converted_pledged_amount': 265, 'country': 'GB', 'created_at': 1455291240, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1457892424, 'dis ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC4\\x81ori ...' for column 'blurb' at row 51")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, parent_id_category, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(parent_id_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 169, 'backers_count': 7, 'blurb': 'The perfect modern tool! A subscription box service of mindful indulgence, personal development and self love to brighten up your month', 'converted_pledged_amount': 237, 'country': 'GB', 'created_at': 1510140295, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1516826543, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 4500.0, 'id': 1926584769, 'is_starrable': 1, 'launched_at': 1514320943, 'name': 'BOUXBOX: Subscription Box With Your Happiness In Mind!', 'pledged': 175.0, 'slug': 'bouxbox-subscription-box-with-your-happiness-in-mi', 'source_url': 'https://www.kickstarter.com/discover/categories/crafts/diy', 'spotlight': 0, 'staff_pick': 0, 'state': 'live', 'state_changed_at': 1514320944, 'static_usd_rate': 1.33644993, 'usd_pledged': 233.87873775, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 16744876, 'name_category': 'DIY', 'id_category': 345, 'position_category': 3, 'slug_category': 'crafts/diy', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/crafts/diy', 'parent_id_category': 26.0, 'country_location': 'GB', 'name_location': 'London', 'displayable_name_location': 'London, UK', 'short_name_location': 'London, UK', 'id_location': 44418.0, 'state_location': 'England', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'london-gb', 'localized_name_location': 'London', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/london-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/london-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515869922.3c4653dae7508dbfed9270a9388456c6329d7884&woe_id=44418', 'small_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=160&h=90&fit=crop&v=1514598008&auto=format&q=92&s=759579e9d3f6eb5fd536db3dd0de8d86', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=48&h=27&fit=crop&v=1514598008&auto=format&q=92&s=0e5d115a61014d86d7af8d0cadbcb8b6', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=1024&h=576&fit=crop&v=1514598008&auto=format&q=92&s=52c8ec3de5411e69dd78bcdac2454b41', 'med_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=272&h=153&fit=crop&v=1514598008&auto=format&q=92&s=9d24dad4ca5bf36f40a72b3739cba686', 'key_photo': 'assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=1552&h=873&fit=crop&v=1514598008&auto=format&q=92&s=ebd2ca45473147e2c0354087c2bbd734', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=352&h=198&fit=crop&v=1514598008&auto=format&q=92&s=6c681de6c05af09f7e7e9a9f051fcc60', 'full_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=560&h=315&fit=crop&v=1514598008&auto=format&q=92&s=7b061b4ee2de44eb044049889de7712d', 'little_photo': 'https://ksr-ugc.imgix.net/assets/019/687/409/2929df5899a31a876341aaa5e9b13875_original.png?crop=faces&w=208&h=117&fit=crop&v=1514598008&auto=format&q=92&s=026b57d214ddc87fd00f60441c3185e5'}, {'index': 178, 'backers_count': 0, 'blurb': 'Natural Fibre Bedding company producing personalised New Baby duvets from luxurious Alpaca and Wool, sleeping naturally from the start.', 'converted_pledged_amount': 0, 'country': 'GB', 'created_at': 1455899444, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1458408060, 'disable_communication': 0, ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC5\\x91t\\xC3\\xA1r...' for column 'name_location' at row 45")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, parent_id_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(parent_id_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xE2\\x80\\xA8It ...' for column 'blurb' at row 100")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, parent_id_category, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(parent_id_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 12, 'backers_count': 7, 'blurb': 'Sudden death is a reality for all! \r\nLeave your loved ones  with precious last words and memories from you in the case of sudden death!', 'converted_pledged_amount': 257, 'country': 'GB', 'created_at': 1513357861, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1516563995, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 1000.0, 'id': 1107426852, 'is_starrable': 1, 'launched_at': 1513712795, 'name': 'Open Me....When I Am Dead My Parting Memory Book', 'pledged': 190.0, 'slug': 'open-mewhen-i-am-dead-my-parting-memory-book', 'source_url': 'https://www.kickstarter.com/discover/categories/journalism', 'spotlight': 0, 'staff_pick': 0, 'state': 'live', 'state_changed_at': 1513712795, 'static_usd_rate': 1.33335644, 'usd_pledged': 253.3377236, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 1228010, 'name_category': 'Journalism', 'id_category': 13, 'position_category': 10, 'slug_category': 'journalism', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/journalism', 'parent_id_category': None, 'country_location': 'GB', 'name_location': 'Leicester', 'displayable_name_location': 'Leicester, UK', 'short_name_location': 'Leicester, UK', 'id_location': 26062.0, 'state_location': 'England', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'leicester-gb', 'localized_name_location': 'Leicester', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/leicester-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/leicester-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515840796.06aed15ac592f509e9304a24389b3ebbac2ff5cc&woe_id=26062', 'small_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=160&h=90&fit=crop&v=1514072772&auto=format&q=92&s=6a9f702865a6b7716fef60dfe6daea51', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=48&h=27&fit=crop&v=1514072772&auto=format&q=92&s=c12b3dd3a2afbae015d2fd3bd42d1cfe', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=1024&h=576&fit=crop&v=1514072772&auto=format&q=92&s=fe5134bd2cf2169eaa8b17f7fd7a8319', 'med_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=272&h=153&fit=crop&v=1514072772&auto=format&q=92&s=0800bb7fdccd55ebf5e7fe25a93d3362', 'key_photo': 'assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=1552&h=873&fit=crop&v=1514072772&auto=format&q=92&s=1b4acd5fe03dee4842c7ad28ee8e83d0', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=352&h=198&fit=crop&v=1514072772&auto=format&q=92&s=1f0c334cc7847820594337dba26335f5', 'full_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=560&h=315&fit=crop&v=1514072772&auto=format&q=92&s=ddc574bab0935b25575cc010a693edf2', 'little_photo': 'https://ksr-ugc.imgix.net/assets/019/610/884/786cfe553019425809b220ee0ba0a30d_original.jpg?crop=faces&w=208&h=117&fit=crop&v=1514072772&auto=format&q=92&s=df641ccba0a25b828d41f08679cadde4'}, {'index': 22, 'backers_count': 4, 'blurb': 'ESIMBI magazine is about developing the entrepreneurial spirit of talents in Congo and the diaspora.', 'converted_pledged_amount': 78, 'country': 'GB', 'created_at': 1510014734, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1517626132, 'disable_communication': 0, 'fx_rate': 1.354969 ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC4\\xABga i...' for column 'blurb' at row 57")
# [SQL: INSERT INTO l0e (`index`, backers_count, blurb, converted_pledged_amount, country, created_at, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, fx_rate, goal, id, is_starrable, launched_at, name, pledged, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, usd_pledged, usd_type, friends, is_backing, is_starred, permissions, color_category, parent_id_category, name_category, id_category, position_category, slug_category, `urls.web.discover_category`, country_location, name_location, displayable_name_location, short_name_location, id_location, state_location, type_location, is_root_location, slug_location, localized_name_location, `urls.web.discover_location`, `urls.web.location_location`, `urls.api.nearby_projects_location`, small_photo, thumb_photo, `1024x576_photo`, med_photo, key_photo, `1536x864_photo`, ed_photo, full_photo, little_photo) VALUES (%(index)s, %(backers_count)s, %(blurb)s, %(converted_pledged_amount)s, %(country)s, %(created_at)s, %(currency)s, %(currency_symbol)s, %(currency_trailing_code)s, %(current_currency)s, %(deadline)s, %(disable_communication)s, %(fx_rate)s, %(goal)s, %(id)s, %(is_starrable)s, %(launched_at)s, %(name)s, %(pledged)s, %(slug)s, %(source_url)s, %(spotlight)s, %(staff_pick)s, %(state)s, %(state_changed_at)s, %(static_usd_rate)s, %(usd_pledged)s, %(usd_type)s, %(friends)s, %(is_backing)s, %(is_starred)s, %(permissions)s, %(color_category)s, %(parent_id_category)s, %(name_category)s, %(id_category)s, %(position_category)s, %(slug_category)s, %(urls.web.discover_category)s, %(country_location)s, %(name_location)s, %(displayable_name_location)s, %(short_name_location)s, %(id_location)s, %(state_location)s, %(type_location)s, %(is_root_location)s, %(slug_location)s, %(localized_name_location)s, %(urls.web.discover_location)s, %(urls.web.location_location)s, %(urls.api.nearby_projects_location)s, %(small_photo)s, %(thumb_photo)s, %(1024x576_photo)s, %(med_photo)s, %(key_photo)s, %(1536x864_photo)s, %(ed_photo)s, %(full_photo)s, %(little_photo)s)]
# [parameters: ({'index': 246, 'backers_count': 8, 'blurb': 'We are developing a collaborative platform for news storytelling on Africa, and, want to provide journalism training via our website', 'converted_pledged_amount': 71, 'country': 'GB', 'created_at': 1411562976, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1421880245, 'disable_communication': 0, 'fx_rate': 1.35496949, 'goal': 10000.0, 'id': 1037670307, 'is_starrable': 0, 'launched_at': 1419288245, 'name': 'Collaborative News on Africa', 'pledged': 47.0, 'slug': 'collaborative-news-on-africa', 'source_url': 'https://www.kickstarter.com/discover/categories/journalism/web', 'spotlight': 0, 'staff_pick': 1, 'state': 'failed', 'state_changed_at': 1421880245, 'static_usd_rate': 1.56252441, 'usd_pledged': 73.43864727, 'usd_type': 'domestic', 'friends': None, 'is_backing': None, 'is_starred': None, 'permissions': None, 'color_category': 1228010, 'parent_id_category': 13.0, 'name_category': 'Web', 'id_category': 361, 'position_category': 5, 'slug_category': 'journalism/web', 'urls.web.discover_category': 'http://www.kickstarter.com/discover/categories/journalism/web', 'country_location': 'GB', 'name_location': 'Birmingham', 'displayable_name_location': 'Birmingham, UK', 'short_name_location': 'Birmingham, UK', 'id_location': 12723.0, 'state_location': 'England', 'type_location': 'Town', 'is_root_location': 0, 'slug_location': 'birmingham-gb', 'localized_name_location': 'Birmingham', 'urls.web.discover_location': 'https://www.kickstarter.com/discover/places/birmingham-gb', 'urls.web.location_location': 'https://www.kickstarter.com/locations/birmingham-gb', 'urls.api.nearby_projects_location': 'https://api.kickstarter.com/v1/discover?signature=1515840764.70f891069fc550cf45df4162d2ef9d0e52120062&woe_id=12723', 'small_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=160&h=90&fit=crop&v=1463709020&auto=format&q=92&s=9b9de0c1eaaf1a4589966bc2aa9026a8', 'thumb_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=48&h=27&fit=crop&v=1463709020&auto=format&q=92&s=4c205230bde52f2913e2f4314277c692', '1024x576_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=1024&h=576&fit=crop&v=1463709020&auto=format&q=92&s=a2b7bd57e33740a27f2f819aa9019c37', 'med_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=272&h=153&fit=crop&v=1463709020&auto=format&q=92&s=d7783bc80ab8053f4291929fa5312891', 'key_photo': 'assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg', '1536x864_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=1552&h=873&fit=crop&v=1463709020&auto=format&q=92&s=3eac2865b74632beb93607b8029db89a', 'ed_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=352&h=198&fit=crop&v=1463709020&auto=format&q=92&s=ed70fa1b340a2b297fa3ff8e5b257981', 'full_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=560&h=315&fit=crop&v=1463709020&auto=format&q=92&s=142843fd70dbefb44e665b94afe4ffef', 'little_photo': 'https://ksr-ugc.imgix.net/assets/011/877/639/15159437ba5767b8a02bcae96d70aec9_original.jpg?crop=faces&w=208&h=117&fit=crop&v=1463709020&auto=format&q=92&s=4955c1451bc37488de1647d3ba6ce5bc'}, {'index': 247, 'backers_count': 1, 'blurb': 'Made from sent in stories, and online posts from facebook and twitter etc,  I need the funds for advertisement to get  publishers', 'converted_pledged_amount': 4, 'country': 'GB', 'created_at': 1419350084, 'currency': 'GBP', 'currency_symbol': '£', 'currency_trailing_code': 0, 'current_currency': 'USD', 'deadline': 1422031307, 'disable_communication': 0, 'fx_rate': 1.3549 ...
# (Background on this error at: http://sqlalche.me/e/2j85)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-205f0446c818> in <module>
#      17             location = getLocation(dataset)
#      18             dataset= merge(dataset,location,'location')
# ---> 19             photo = getPhoto(dataset)
#      20             dataset= merge(dataset,photo,'photo')
#      21             del dataset['urls']
#
# <ipython-input-9-c1bba00fd380> in getPhoto(dataset)
#       1 def getPhoto(dataset):
# ----> 2     normalized_Photo=pd.json_normalize(dataset.photo.apply(besteffort_loads))
#       3     normalized_Photo.columns=normalized_Photo.columns.map(lambda x: str(x) + '_photo')
#       4     return normalized_Photo
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     276             # TODO: handle record value which are lists, at least error
#     277             #       reasonably
# --> 278             data = nested_to_record(data, sep=sep, max_level=max_level)
#     279         return DataFrame(data)
#     280     elif not isinstance(record_path, list):
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\io\json\_normalize.py in nested_to_record(ds, prefix, sep, level, max_level)
#      79     new_ds = []
#      80     for d in ds:
# ---> 81         new_d = copy.deepcopy(d)
#      82         for k, v in d.items():
#      83             # each key gets renamed with prefix
#
# ~\anaconda3\envs\Tesi_Workspace\lib\copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~\anaconda3\envs\Tesi_Workspace\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~\anaconda3\envs\Tesi_Workspace\lib\copy.py in deepcopy(x, memo, _nil)
#     139         memo = {}
#     140
# --> 141     d = id(x)
#     142     y = memo.get(d, _nil)
#     143     if y is not _nil:
#
# KeyboardInterrupt:

# %%
#salvataggio in csv
query="select * from l0 "
result_query=sql.read_sql_query(query,engine)
result_query['state']=result_query['state'].astype(int)
result_query.to_csv('csv/2018-2019.csv')

# %%
dataset=pd.read_csv('csv/2018-2019.csv')
del dataset['level_0']
sql.to_sql(dataset,con=engine,name='l0',if_exists='replace')

# %%
u=pd.read_csv('../csv/2016/8/kickstarter001.csv')
b=pd.read_csv('../csv/2018/3/kickstarter001.csv')

# %%
u.columns
# Out:
# Index(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'backers_count', 'static_usd_rate',
#        'usd_pledged', 'creator', 'location', 'category', 'profile',
#        'spotlight', 'urls', 'source_url', 'friends', 'is_starred',
#        'is_backing', 'permissions'],
#       dtype='object')

# %%
b.columns
# Out:
# 'A letterpress book/audiobook about an elephant who discovers  beauty in the world around him. Based on the Japanese song “Zōsan”'

# %%
b=pd.read_csv('../csv/2018/1/kickstarter001.csv')
category= getCategory(b)
b= merge(b,category,'category')
location = getLocation(b)
dataset= merge(b,location,'location')
photo = getPhoto(b)
dataset= merge(b,photo,'photo')
del b['urls']
del b['creator']
del b['profile']
b['blurb'] = b['blurb'].apply(lambda x: ''.join([" " if ord(i) < 32 or ord(i) > 126 else i for i in range(x)]))
#b.to_sql('l0gb',con=engine,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-deb1fe943f35> in <module>
#       9 del b['creator']
#      10 del b['profile']
# ---> 11 b['blurb'] = b['blurb'].apply(lambda x: ''.join([" " if ord(i) < 32 or ord(i) > 126 else i for i in range(x)]))
#      12 #b.to_sql('l0gb',con=engine,if_exists='append')
#
# ~\anaconda3\envs\Tesi_Workspace\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-39-deb1fe943f35> in <lambda>(x)
#       9 del b['creator']
#      10 del b['profile']
# ---> 11 b['blurb'] = b['blurb'].apply(lambda x: ''.join([" " if ord(i) < 32 or ord(i) > 126 else i for i in range(x)]))
#      12 #b.to_sql('l0gb',con=engine,if_exists='append')
#
# TypeError: 'str' object cannot be interpreted as an integer
