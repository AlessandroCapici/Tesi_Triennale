# %% [markdown]
# # Analisi dei dati italiani
# in questo file andrò ad analizzare i dati italiani di maggio 2019

# %% [markdown]
# ## Import utili

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import urllib.request
import imquality.brisque as brisque
import PIL.Image
from pandas.io import sql
import datetime
from sqlalchemy import create_engine

# %% [markdown]
# ## Connessione al database
# Uso create_engine per creare la connessione
#
# Ha un parametro dove bisogna specificare:
#    - **User**
#    - **Password**
#    - **Host**
#    - **Schema**

# %%
engine = create_engine('mysql+pymysql://root:password@localhost/kickstarter')

# %% [markdown]
# # IP1
# ## Analisi delle donazioni per uno specifico progetto data qualità delle foto
#
# prendo tutte le foto e ne calcolo l indice

# %%
query="select state , backers_count, little_photo from l0 where state='successful' or state='failed'"
result_query=sql.read_sql_query(query,engine)

# %%
score = []

# %%
for i in range (0,result_query.size-1):
    photo=result_query['little_photo'].values[i]
    img=urllib.request.urlopen(photo)
    a=plt.imread(img,0)
    try:
        score.append(brisque.score(a))
    except:
        score.append(0)
        continue
    print(i)
result_query['score']=score
# Out:
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 0
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 2
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 3
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 4
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 5
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 6
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 7
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 8
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 9
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 10
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 11
# 12
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 13
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 14
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 15
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 16
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 17
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 18
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 19
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 20
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 21
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 22
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 23
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 24
# 25
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 26
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 27
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 28
# 29
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 30
# 31
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 32
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 33
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 34
# 35
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 36
# 37
# 38
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 39
# 40
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 41
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 42
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 43
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 44
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 45
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 46
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 47
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 48
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 49
# 50
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 51
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 52
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 53
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 54
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 55
# 56
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 57
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 58
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 59
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 60
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 61
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 62
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 63
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 64
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 65
# 66
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 67
# 68
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 69
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 70
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 71
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 72
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 73
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 74
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 75
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 76
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 77
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 78
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 79
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 80
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 81
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 82
# 83
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 84
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 85
# 86
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 87
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 88
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 89
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 90
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 91
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 92
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 93
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 94
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 95
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 96
# ...
#   self.image = skimage.color.rgb2gray(self.image)
# 1347
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1348
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1349
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1350
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1351
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1352
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1353
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1354
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1355
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1356
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1357
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1358
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1359
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1360
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1361
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1362
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1363
# 1364
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1365
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1366
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1367
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1368
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1369
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1370
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1371
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1372
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1373
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1374
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1375
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1376
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1377
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1378
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1379
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# C:\Users\CAPO\anaconda3\envs\Tesi_Workspace\lib\site-packages\imquality\brisque.py:44: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   self.image = skimage.color.rgb2gray(self.image)
# 1380
# 1381
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-904b481f20ca> in <module>
#       1 for i in range (0,result_query.size-1):
# ----> 2     photo=result_query['little_photo'].values[i]
#       3     img=urllib.request.urlopen(photo)
#       4     a=plt.imread(img,0)
#       5     try:
#
# IndexError: index 1382 is out of bounds for axis 0 with size 1382

# %%
result_query
# Out:
#            state  backers_count  \
# 0         failed              1
# 1         failed              3
# 2         failed             10
# 3     successful             10
# 4         failed              2
# ...          ...            ...
# 1377      failed              3
# 1378      failed              0
# 1379      failed              5
# 1380  successful             74
# 1381      failed             13
#
#                                            little_photo       score
# 0     https://ksr-ugc.imgix.net/assets/012/441/677/d...  117.890800
# 1     https://ksr-ugc.imgix.net/assets/024/376/496/3...   15.006671
# 2     https://ksr-ugc.imgix.net/assets/015/551/532/3...   48.136761
# 3     https://ksr-ugc.imgix.net/assets/023/129/669/b...   16.778417
# 4     https://ksr-ugc.imgix.net/assets/022/796/715/0...  130.060796
# ...                                                 ...         ...
# 1377  https://ksr-ugc.imgix.net/assets/012/170/844/6...   40.242527
# 1378  https://ksr-ugc.imgix.net/assets/012/370/394/2...   21.538117
# 1379  https://ksr-ugc.imgix.net/assets/022/239/481/1...   -0.422935
# 1380  https://ksr-ugc.imgix.net/assets/022/530/249/c...   74.482488
# 1381  https://ksr-ugc.imgix.net/assets/015/404/098/7...    3.163305
#
# [1382 rows x 4 columns]

# %%
photo=result['little_photo'].values[223]
img=urllib.request.urlopen(photo)
a=plt.imread(img,0)
plt.imshow(a)
